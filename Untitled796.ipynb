# %%
import os
import json
import yaml
import joblib
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings("ignore")

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.cluster import KMeans

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical

# =========================
# PATH SETTINGS
# =========================

DATASET_PATH = r"C:\Users\NXTWAVE\Downloads\Smart Agricultural Market Intelligence System\megambmarketname_n.xls"
OUTPUT_DIR = r"C:\Users\NXTWAVE\Downloads\Smart Agricultural Market Intelligence System"

os.makedirs(OUTPUT_DIR, exist_ok=True)

PREFIX = "ais_"

# =========================
# LOAD DATA
# =========================

df = pd.read_excel(DATASET_PATH)

df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
)

df = df.dropna()
df = df.drop_duplicates()

for col in df.columns:
    df[col] = df[col].astype(str).str.strip()

print("Dataset Loaded Successfully")
print(df.head())

# =========================
# FEATURE ENGINEERING
# =========================

district_market_count = df.groupby("district_name")["market_name"].count().to_dict()
block_market_count = df.groupby("block_name")["market_name"].count().to_dict()

df["district_market_count"] = df["district_name"].map(district_market_count)
df["block_market_count"] = df["block_name"].map(block_market_count)

df["market_name_length"] = df["market_name"].apply(len)
df["block_name_length"] = df["block_name"].apply(len)
df["district_name_length"] = df["district_name"].apply(len)

df["market_score"] = (
    df["district_market_count"] * 0.4 +
    df["block_market_count"] * 0.5 +
    df["market_name_length"] * 0.1
)

df["market_category"] = pd.qcut(
    df["market_score"],
    q=3,
    labels=["Low", "Medium", "High"],
    duplicates="drop"
)

# =========================
# ENCODING
# =========================

label_encoders = {}

for col in ["district_name", "block_name", "market_name", "market_category"]:
    le = LabelEncoder()
    df[col + "_encoded"] = le.fit_transform(df[col])
    label_encoders[col] = le

# =========================
# FEATURES
# =========================

features = [
    "district_name_encoded",
    "block_name_encoded",
    "market_name_encoded",
    "district_market_count",
    "block_market_count",
    "market_name_length",
    "block_name_length",
    "district_name_length",
    "market_score"
]

X = df[features]
y = df["market_category_encoded"]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# =========================
# AIS FEATURE SELECTION
# =========================

def fitness_function(mask, X_data, y_data):
    selected_features = np.where(mask == 1)[0]

    if len(selected_features) == 0:
        return 0

    X_selected = X_data[:, selected_features]

    X_train, X_test, y_train, y_test = train_test_split(
        X_selected,
        y_data,
        test_size=0.2,
        random_state=42,
        stratify=y_data if len(np.unique(y_data)) > 1 else None
    )

    model = RandomForestClassifier(
        n_estimators=100,
        random_state=42,
        max_depth=8
    )

    model.fit(X_train, y_train)
    preds = model.predict(X_test)

    accuracy = accuracy_score(y_test, preds)

    feature_penalty = len(selected_features) / X_data.shape[1]

    fitness = accuracy - (0.01 * feature_penalty)

    return fitness


def ais_feature_selection(X_data, y_data, population_size=20, generations=30, clone_factor=5, mutation_rate=0.1):
    n_features = X_data.shape[1]

    population = np.random.randint(0, 2, size=(population_size, n_features))

    best_solution = None
    best_fitness = -np.inf
    fitness_history = []

    for gen in range(generations):
        fitness_scores = np.array([
            fitness_function(individual, X_data, y_data)
            for individual in population
        ])

        sorted_indices = np.argsort(fitness_scores)[::-1]
        population = population[sorted_indices]
        fitness_scores = fitness_scores[sorted_indices]

        if fitness_scores[0] > best_fitness:
            best_fitness = fitness_scores[0]
            best_solution = population[0].copy()

        selected = population[:population_size // 2]

        clones = []

        for antibody in selected:
            for _ in range(clone_factor):
                clone = antibody.copy()

                for i in range(n_features):
                    if np.random.rand() < mutation_rate:
                        clone[i] = 1 - clone[i]

                if np.sum(clone) == 0:
                    clone[np.random.randint(0, n_features)] = 1

                clones.append(clone)

        clones = np.array(clones)

        combined_population = np.vstack((population, clones))

        combined_fitness = np.array([
            fitness_function(individual, X_data, y_data)
            for individual in combined_population
        ])

        best_indices = np.argsort(combined_fitness)[::-1][:population_size]

        population = combined_population[best_indices]

        fitness_history.append(best_fitness)

        print(f"Generation {gen + 1}/{generations} | Best Fitness: {best_fitness:.4f}")

    return best_solution, best_fitness, fitness_history


best_mask, best_fitness, fitness_history = ais_feature_selection(X_scaled, y)

selected_feature_indices = np.where(best_mask == 1)[0]
selected_features = [features[i] for i in selected_feature_indices]

print("\nSelected Features by AIS:")
print(selected_features)

X_selected = X_scaled[:, selected_feature_indices]

# =========================
# CLUSTERING
# =========================

kmeans = KMeans(n_clusters=3, random_state=42)
df["ais_market_cluster"] = kmeans.fit_predict(X_selected)

# =========================
# TRAIN TEST SPLIT
# =========================

X_train, X_test, y_train, y_test = train_test_split(
    X_selected,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y if len(np.unique(y)) > 1 else None
)

# =========================
# RANDOM FOREST
# =========================

rf_model = RandomForestClassifier(
    n_estimators=200,
    random_state=42,
    max_depth=10
)

rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)
rf_accuracy = accuracy_score(y_test, rf_pred)

# =========================
# GRADIENT BOOSTING
# =========================

gb_model = GradientBoostingClassifier(random_state=42)

gb_model.fit(X_train, y_train)
gb_pred = gb_model.predict(X_test)
gb_accuracy = accuracy_score(y_test, gb_pred)

# =========================
# NEURAL NETWORK
# =========================

num_classes = len(np.unique(y))

y_train_cat = to_categorical(y_train, num_classes=num_classes)
y_test_cat = to_categorical(y_test, num_classes=num_classes)

nn_model = Sequential([
    Dense(64, activation="relu", input_shape=(X_train.shape[1],)),
    Dropout(0.2),
    Dense(32, activation="relu"),
    Dropout(0.2),
    Dense(num_classes, activation="softmax")
])

nn_model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

history = nn_model.fit(
    X_train,
    y_train_cat,
    epochs=50,
    batch_size=8,
    validation_data=(X_test, y_test_cat),
    verbose=1
)

nn_loss, nn_accuracy = nn_model.evaluate(X_test, y_test_cat, verbose=0)

# =========================
# SAVE MODELS
# =========================

nn_model.save(os.path.join(OUTPUT_DIR, PREFIX + "market_intelligence_model.h5"))

joblib.dump(rf_model, os.path.join(OUTPUT_DIR, PREFIX + "random_forest_model.pkl"))
joblib.dump(gb_model, os.path.join(OUTPUT_DIR, PREFIX + "gradient_boosting_model.pkl"))
joblib.dump(kmeans, os.path.join(OUTPUT_DIR, PREFIX + "kmeans_model.pkl"))
joblib.dump(scaler, os.path.join(OUTPUT_DIR, PREFIX + "scaler.pkl"))
joblib.dump(label_encoders, os.path.join(OUTPUT_DIR, PREFIX + "label_encoders.pkl"))
joblib.dump(best_mask, os.path.join(OUTPUT_DIR, PREFIX + "selected_feature_mask.pkl"))

# =========================
# RESULT CSV
# =========================

result_df = pd.DataFrame({
    "Model": ["AIS + Random Forest", "AIS + Gradient Boosting", "AIS + Neural Network"],
    "Accuracy": [rf_accuracy, gb_accuracy, nn_accuracy]
})

result_df.to_csv(os.path.join(OUTPUT_DIR, PREFIX + "result.csv"), index=False)

# =========================
# PREDICTION CSV
# =========================

df["ais_rf_prediction_encoded"] = rf_model.predict(X_selected)
df["ais_gb_prediction_encoded"] = gb_model.predict(X_selected)

nn_full_pred = nn_model.predict(X_selected)
df["ais_nn_prediction_encoded"] = np.argmax(nn_full_pred, axis=1)

category_encoder = label_encoders["market_category"]

df["ais_rf_prediction"] = category_encoder.inverse_transform(df["ais_rf_prediction_encoded"])
df["ais_gb_prediction"] = category_encoder.inverse_transform(df["ais_gb_prediction_encoded"])
df["ais_nn_prediction"] = category_encoder.inverse_transform(df["ais_nn_prediction_encoded"])

df.to_csv(os.path.join(OUTPUT_DIR, PREFIX + "prediction.csv"), index=False)

# =========================
# JSON METRICS
# =========================

metrics = {
    "optimization_algorithm": "Artificial Immune System",
    "ais_best_fitness": float(best_fitness),
    "selected_features": selected_features,
    "random_forest_accuracy": float(rf_accuracy),
    "gradient_boosting_accuracy": float(gb_accuracy),
    "neural_network_accuracy": float(nn_accuracy),
    "total_records": int(len(df)),
    "total_districts": int(df["district_name"].nunique()),
    "total_blocks": int(df["block_name"].nunique()),
    "total_markets": int(df["market_name"].nunique())
}

with open(os.path.join(OUTPUT_DIR, PREFIX + "metrics.json"), "w") as f:
    json.dump(metrics, f, indent=4)

# =========================
# YAML CONFIG
# =========================

config = {
    "project_name": "Smart Agricultural Market Intelligence System",
    "author": "Sagnik Patra",
    "optimization_algorithm": "Artificial Immune System",
    "dataset_path": DATASET_PATH,
    "output_directory": OUTPUT_DIR,
    "all_features": features,
    "selected_features": selected_features,
    "target": "market_category",
    "models": {
        "random_forest": PREFIX + "random_forest_model.pkl",
        "gradient_boosting": PREFIX + "gradient_boosting_model.pkl",
        "neural_network": PREFIX + "market_intelligence_model.h5",
        "kmeans": PREFIX + "kmeans_model.pkl"
    },
    "outputs": {
        "result_csv": PREFIX + "result.csv",
        "prediction_csv": PREFIX + "prediction.csv",
        "accuracy_graph": PREFIX + "accuracy_graph.png",
        "heatmap": PREFIX + "heatmap.png",
        "comparison_graph": PREFIX + "comparison_graph.png",
        "result_graph": PREFIX + "result_graph.png",
        "prediction_graph": PREFIX + "prediction_graph.png",
        "optimization_graph": PREFIX + "optimization_graph.png"
    }
}

with open(os.path.join(OUTPUT_DIR, PREFIX + "config.yaml"), "w") as f:
    yaml.dump(config, f, default_flow_style=False)

# =========================
# GRAPH 1: ACCURACY GRAPH
# =========================

plt.figure(figsize=(8, 5))
plt.bar(result_df["Model"], result_df["Accuracy"])
plt.title("AIS Model Accuracy Comparison")
plt.xlabel("Models")
plt.ylabel("Accuracy")
plt.ylim(0, 1)
plt.xticks(rotation=15)
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, PREFIX + "accuracy_graph.png"))
plt.show()

# =========================
# GRAPH 2: HEATMAP
# =========================

plt.figure(figsize=(10, 7))
heatmap_data = df[selected_features + ["market_category_encoded", "ais_market_cluster"]]
sns.heatmap(heatmap_data.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("AIS Selected Feature Correlation Heatmap")
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, PREFIX + "heatmap.png"))
plt.show()

# =========================
# GRAPH 3: COMPARISON GRAPH
# =========================

plt.figure(figsize=(8, 5))
plt.plot(result_df["Model"], result_df["Accuracy"], marker="o")
plt.title("AIS Model Performance Comparison")
plt.xlabel("Models")
plt.ylabel("Accuracy")
plt.ylim(0, 1)
plt.grid(True)
plt.xticks(rotation=15)
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, PREFIX + "comparison_graph.png"))
plt.show()

# =========================
# GRAPH 4: RESULT GRAPH
# =========================

plt.figure(figsize=(8, 5))
actual_counts = df["market_category"].value_counts()
plt.bar(actual_counts.index, actual_counts.values)
plt.title("Actual Market Category Distribution")
plt.xlabel("Market Category")
plt.ylabel("Count")
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, PREFIX + "result_graph.png"))
plt.show()

# =========================
# GRAPH 5: PREDICTION GRAPH
# =========================

plt.figure(figsize=(8, 5))
pred_counts = df["ais_rf_prediction"].value_counts()
plt.bar(pred_counts.index, pred_counts.values)
plt.title("AIS Predicted Market Category Distribution")
plt.xlabel("Predicted Category")
plt.ylabel("Count")
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, PREFIX + "prediction_graph.png"))
plt.show()

# =========================
# GRAPH 6: AIS OPTIMIZATION GRAPH
# =========================

plt.figure(figsize=(8, 5))
plt.plot(range(1, len(fitness_history) + 1), fitness_history, marker="o")
plt.title("AIS Optimization Progress")
plt.xlabel("Generation")
plt.ylabel("Best Fitness")
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, PREFIX + "optimization_graph.png"))
plt.show()

# =========================
# GRAPH 7: NN TRAINING ACCURACY GRAPH
# =========================

plt.figure(figsize=(8, 5))
plt.plot(history.history["accuracy"], label="Training Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.title("AIS Neural Network Training Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, PREFIX + "nn_training_accuracy_graph.png"))
plt.show()

# =========================
# GRAPH 8: CONFUSION MATRIX
# =========================

cm = confusion_matrix(y_test, rf_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("AIS Random Forest Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, PREFIX + "confusion_matrix.png"))
plt.show()

# =========================
# FINAL OUTPUT
# =========================

print("\nAll AIS files saved successfully in:")
print(OUTPUT_DIR)

print("\nGenerated AIS Files:")
print(PREFIX + "market_intelligence_model.h5")
print(PREFIX + "random_forest_model.pkl")
print(PREFIX + "gradient_boosting_model.pkl")
print(PREFIX + "kmeans_model.pkl")
print(PREFIX + "scaler.pkl")
print(PREFIX + "label_encoders.pkl")
print(PREFIX + "selected_feature_mask.pkl")
print(PREFIX + "config.yaml")
print(PREFIX + "metrics.json")
print(PREFIX + "result.csv")
print(PREFIX + "prediction.csv")
print(PREFIX + "accuracy_graph.png")
print(PREFIX + "heatmap.png")
print(PREFIX + "comparison_graph.png")
print(PREFIX + "result_graph.png")
print(PREFIX + "prediction_graph.png")
print(PREFIX + "optimization_graph.png")
print(PREFIX + "nn_training_accuracy_graph.png")
print(PREFIX + "confusion_matrix.png")
# Out:
# Dataset Loaded Successfully
#      district_name      block_name  market_name
# 0  East Garo Hills  Dambo Rongjeng     Rongjeng
# 1  East Garo Hills        Kharkuta     Adokgiri
# 2  East Garo Hills        Kharkuta    Kharkutta
# 3  East Garo Hills     Resubelpara   Bajengdoba
# 4  East Garo Hills     Resubelpara  Mendipathar
# Generation 1/30 | Best Fitness: 0.9956
# Generation 2/30 | Best Fitness: 0.9956
# Generation 3/30 | Best Fitness: 0.9978
# Generation 4/30 | Best Fitness: 0.9978
# Generation 5/30 | Best Fitness: 0.9989
# Generation 6/30 | Best Fitness: 0.9989
# Generation 7/30 | Best Fitness: 0.9989
# Generation 8/30 | Best Fitness: 0.9989
# Generation 9/30 | Best Fitness: 0.9989
# Generation 10/30 | Best Fitness: 0.9989
# Generation 11/30 | Best Fitness: 0.9989
# Generation 12/30 | Best Fitness: 0.9989
# Generation 13/30 | Best Fitness: 0.9989
# Generation 14/30 | Best Fitness: 0.9989
# Generation 15/30 | Best Fitness: 0.9989
# Generation 16/30 | Best Fitness: 0.9989
# Generation 17/30 | Best Fitness: 0.9989
# Generation 18/30 | Best Fitness: 0.9989
# Generation 19/30 | Best Fitness: 0.9989
# Generation 20/30 | Best Fitness: 0.9989
# Generation 21/30 | Best Fitness: 0.9989
# Generation 22/30 | Best Fitness: 0.9989
# Generation 23/30 | Best Fitness: 0.9989
# Generation 24/30 | Best Fitness: 0.9989
# Generation 25/30 | Best Fitness: 0.9989
# Generation 26/30 | Best Fitness: 0.9989
# Generation 27/30 | Best Fitness: 0.9989
# Generation 28/30 | Best Fitness: 0.9989
# Generation 29/30 | Best Fitness: 0.9989
# Generation 30/30 | Best Fitness: 0.9989
#
# Selected Features by AIS:
# ['market_score']
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.4898 - loss: 1.0753 - val_accuracy: 0.6154 - val_loss: 1.0285
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5714 - loss: 1.0172 - val_accuracy: 0.6154 - val_loss: 0.9875
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7143 - loss: 0.9689 - val_accuracy: 0.6154 - val_loss: 0.9475
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6531 - loss: 0.9289 - val_accuracy: 0.6154 - val_loss: 0.9096
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6939 - loss: 0.8825 - val_accuracy: 0.6923 - val_loss: 0.8701
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6531 - loss: 0.8649 - val_accuracy: 0.6923 - val_loss: 0.8325
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6939 - loss: 0.8258 - val_accuracy: 0.6923 - val_loss: 0.7945
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7143 - loss: 0.7621 - val_accuracy: 0.6923 - val_loss: 0.7557
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6939 - loss: 0.7470 - val_accuracy: 0.6923 - val_loss: 0.7161
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6939 - loss: 0.6910 - val_accuracy: 0.6923 - val_loss: 0.6826
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6735 - loss: 0.6484 - val_accuracy: 0.6923 - val_loss: 0.6523
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6939 - loss: 0.6135 - val_accuracy: 0.6923 - val_loss: 0.6250
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6939 - loss: 0.5792 - val_accuracy: 0.6923 - val_loss: 0.6023
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6939 - loss: 0.5721 - val_accuracy: 0.6923 - val_loss: 0.5828
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7143 - loss: 0.5349 - val_accuracy: 0.7692 - val_loss: 0.5673
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7143 - loss: 0.5193 - val_accuracy: 0.7692 - val_loss: 0.5571
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7347 - loss: 0.5191 - val_accuracy: 0.7692 - val_loss: 0.5468
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7347 - loss: 0.4873 - val_accuracy: 0.7692 - val_loss: 0.5347
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7551 - loss: 0.4883 - val_accuracy: 0.7692 - val_loss: 0.5241
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7551 - loss: 0.4714 - val_accuracy: 0.7692 - val_loss: 0.5048
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7959 - loss: 0.4525 - val_accuracy: 0.7692 - val_loss: 0.4926
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7959 - loss: 0.4544 - val_accuracy: 0.7692 - val_loss: 0.4854
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7959 - loss: 0.4407 - val_accuracy: 0.7692 - val_loss: 0.4794
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7551 - loss: 0.4329 - val_accuracy: 0.7692 - val_loss: 0.4577
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8367 - loss: 0.3945 - val_accuracy: 0.7692 - val_loss: 0.4434
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8571 - loss: 0.4150 - val_accuracy: 0.7692 - val_loss: 0.4261
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8571 - loss: 0.3622 - val_accuracy: 0.7692 - val_loss: 0.4063
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8776 - loss: 0.3593 - val_accuracy: 0.7692 - val_loss: 0.3892
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9184 - loss: 0.3376 - val_accuracy: 0.8462 - val_loss: 0.3785
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8980 - loss: 0.3386 - val_accuracy: 0.8462 - val_loss: 0.3689
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9184 - loss: 0.3281 - val_accuracy: 0.8462 - val_loss: 0.3514
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9592 - loss: 0.2988 - val_accuracy: 0.8462 - val_loss: 0.3351
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9592 - loss: 0.2884 - val_accuracy: 1.0000 - val_loss: 0.3235
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9592 - loss: 0.2982 - val_accuracy: 0.8462 - val_loss: 0.3179
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9184 - loss: 0.2758 - val_accuracy: 0.8462 - val_loss: 0.3117
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8776 - loss: 0.2773 - val_accuracy: 0.8462 - val_loss: 0.2985
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8776 - loss: 0.2812 - val_accuracy: 0.8462 - val_loss: 0.2885
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9388 - loss: 0.2539 - val_accuracy: 0.8462 - val_loss: 0.2897
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9388 - loss: 0.2325 - val_accuracy: 0.8462 - val_loss: 0.2750
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9388 - loss: 0.2431 - val_accuracy: 1.0000 - val_loss: 0.2606
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8776 - loss: 0.2386 - val_accuracy: 1.0000 - val_loss: 0.2493
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9592 - loss: 0.2176 - val_accuracy: 1.0000 - val_loss: 0.2403
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9388 - loss: 0.2156 - val_accuracy: 1.0000 - val_loss: 0.2336
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9592 - loss: 0.2323 - val_accuracy: 1.0000 - val_loss: 0.2295
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9184 - loss: 0.2191 - val_accuracy: 1.0000 - val_loss: 0.2248
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9184 - loss: 0.2049 - val_accuracy: 1.0000 - val_loss: 0.2227
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9592 - loss: 0.1835 - val_accuracy: 1.0000 - val_loss: 0.2166
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9388 - loss: 0.1906 - val_accuracy: 1.0000 - val_loss: 0.2105
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.1653 - val_accuracy: 1.0000 - val_loss: 0.2057
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.1523 - val_accuracy: 1.0000 - val_loss: 0.1999
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# All AIS files saved successfully in:
# C:\Users\NXTWAVE\Downloads\Smart Agricultural Market Intelligence System
#
# Generated AIS Files:
# ais_market_intelligence_model.h5
# ais_random_forest_model.pkl
# ais_gradient_boosting_model.pkl
# ais_kmeans_model.pkl
# ais_scaler.pkl
# ais_label_encoders.pkl
# ais_selected_feature_mask.pkl
# ais_config.yaml
# ais_metrics.json
# ais_result.csv
# ais_prediction.csv
# ais_accuracy_graph.png
# ais_heatmap.png
# ais_comparison_graph.png
# ais_result_graph.png
# ais_prediction_graph.png
# ais_optimization_graph.png
# ais_nn_training_accuracy_graph.png
# ais_confusion_matrix.png
